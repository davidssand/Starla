# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("mpu_data.csv")

# %%
acceleration = data["acceleration"]
time = data["time"]

# %%
#plt.axis([0, 20, 20, 22.5])
plt.plot(time, acceleration)
plt.show()
