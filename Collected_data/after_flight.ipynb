# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#    Unnamed: 0  time_list  pressure_list  temperature_list  altitude_list  \
# 0           0   0.142439    1014.476638         30.926011      84.073420
# 1           1   0.166546    1014.448964         30.926011      84.060894
# 2           2   0.190810    1014.382182         30.936030      84.060161
# 3           3   0.215253    1014.465203         30.936030      84.044835
# 4           4   0.239492    1014.398420         30.946048      84.041303
#
#    z_velocity_list    x_list    y_list    z_list   sr_list  mpu_status  \
# 0         0.000000  0.066650  0.952881  0.238037  0.000000        True
# 1        -0.008660  0.101074  0.938965  0.166504  0.024107        True
# 2        -0.009164  0.103760  0.935547  0.211182  0.024264        True
# 3        -0.019614  0.145264  0.964600  0.230225  0.024443        True
# 4        -0.022043  0.052979  0.949951  0.206787  0.024239        True
#
#    bme_status
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
time = data["time_list"] 
x_list = data["x_list"]
y_list = data["y_list"]
z_list = data["z_list"]
altitude = data["altitude_list"]
z_velocity = data["z_velocity_list"]
sr_list = data["sr_list"]
pressure = data["pressure_list"]
temperature = data["temperature_list"]

# %%
plt.axis([75, 85,-1.5,0])
plt.plot(time, z_velocity)
plt.title('Z Velocity')
plt.show()

# %%
# plt.axis([46915, 46940,-1,1])
plt.plot(time, temperature)
plt.title('Temperature [ºC]')
plt.show()

# %%
# plt.axis([46915, 46940,-1,1])
plt.plot(time, pressure)
plt.title('Pressure')
plt.show()

# %%
# plt.axis([46915, 46940,-910,-906])
plt.plot(time, altitude)
plt.title('Altitude')
plt.show()

# %%
# plt.axis([10, 20, -0.2, 0.2])
plt.plot(time, y_list)
plt.title('Y Acceleration')
plt.show()

# %%
plt.plot(time, x_list)
plt.title('X Acceleration')
plt.show()

# %%
plt.plot(time, z_list)
plt.title('Z Acceleration')
plt.show()

# %%
# plt.axis([46915, 46940,-910,-906])
plt.plot(time, sr_list)
plt.title('sampling rate')
plt.show()
