# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#    Unnamed: 0  time_list  acceleration_list  altitude_list  z_velocity_list  \
# 0           0   6.897357           3.038574       2.421617         0.000000
# 1           0   6.947751           3.013428       2.418804         0.000000
# 2           1   6.985623           3.006836       2.421648         0.001251
# 3           2   7.023879           3.006592       2.414717        -0.001768
# 4           3   7.054636           3.003418       2.425963         0.004326
#
#      x_list    y_list    z_list   sr_list
# 0 -1.201416 -0.961426  0.875732  0.000000
# 1 -1.212891 -0.957520  0.843018  0.000000
# 2 -1.194580 -0.949463  0.862793  0.037872
# 3 -1.189453 -0.955566  0.861572  0.038256
# 4 -1.197021 -0.950684  0.855713  0.030758

# %%
time = data["time_list"] 
acceleration = data["acceleration_list"]
altitude = data["altitude_list"]
z_velocity = data["z_velocity_list"]

# %%
# plt.axis([46915, 46940,-1,1])
plt.plot(time, z_velocity)
plt.title('Altitude')
plt.show()

# %%
# plt.axis([46915, 46940,-910,-906])
plt.plot(time, altitude)
plt.title('')
plt.show()
