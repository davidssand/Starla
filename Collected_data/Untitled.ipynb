# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#    Unnamed: 0     time_list  acceleration_list  altitude_list  \
# 0           0  46904.447238           2.814453    -897.845998
# 1           0  46904.523440           2.850098    -897.842181
# 2           1  46904.582350           2.796631    -897.843595
# 3           2  46904.631770           2.827881    -897.854756
# 4           3  46904.678044           2.840576    -898.058673
#
#    z_velocity_list  pitch_list  yaw_list  roll_list   sr_list
# 0         0.000000   -1.661731 -0.917849  -0.086446  0.000000
# 1         0.000000   -3.291681 -1.793513  -0.164349  0.000000
# 2        -0.000400   -4.859119 -2.654502  -0.236911  0.058910
# 3        -0.004164   -6.371259 -3.472019  -0.321404  0.049420
# 4        -0.077610   -7.851541 -4.314313  -0.406882  0.046274

# %%
time = data["time_list"] 
acceleration = data["acceleration_list"]
altitude = data["altitude_list"]
z_velocity = data["z_velocity_list"]

# %%
plt.axis([46915, 46940,-1,1])
plt.plot(time, z_velocity)
plt.title('Altitude')
plt.show()

# %%
plt.axis([46915, 46940,-910,-906])
plt.plot(time, altitude)
plt.title('')
plt.show()
