# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
data = pd.read_csv("data2.csv")

# %%
data.memory_usage(index=True).sum()
# Out:
# 58760

# %%
data.shape
# Out:
# (815, 9)

# %%
altitude = data["altitude_list"]
accel = data["acceleration_list"]
z_velocity = data["z_velocity_list"]
pitch = data["pitch_list"]
yaw = data["yaw_list"]
roll = data["roll_list"]
sr = data["sr_list"]
time = data["time_list"]

# %%
#plt.axis([3, 44, 1.1, 1.2])
plt.plot(time, accel)
plt.show()

# %%
#plt.axis([0, 40, -5, -2])
plt.plot(time, altitude)
plt.show()

# %%
#plt.axis([0, 40, -0.7, 0.7])
plt.plot(time, z_velocity)
plt.show()

# %%
plt.axis([5, 20, 0.02, 0.05])
plt.plot(time, sr)
plt.show()

# %%
plt.plot(time, pitch)
plt.show()

# %%
plt.plot(time, yaw)
plt.show()

# %%
plt.plot(time, roll)
plt.show()
