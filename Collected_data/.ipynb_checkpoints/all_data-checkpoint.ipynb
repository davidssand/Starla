# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("bme_data.csv")

# %%
altitude = data["altitude"]
z_velocity = data["z_velocity"]
temperature = data["temp_list"]
pressure = data["pressure_list"]
time = data["time"]

# %%
#plt.axis([0, 20, 101420, 101460])
plt.plot(time, altitude, time, z_velocity)#, time, temperature, time, pressure)
plt.show()
